# %%
import pandas as pd

# 파일 경로를 지정합니다
file_path = '소상공인시장진흥공단_상가(상권)정보_부산_202112.csv'

# %%
# CSV 파일을 불러옵니다
data = pd.read_csv(file_path, encoding='utf-8', sep=',', quotechar='"')

# %%
data.head().T
# Out:
#                                    0                          1  \
# 상가업소번호                      23206623                   20418637
# 상호명                              미광장                      BHC치킨
# 지점명                              NaN                        동래점
# 상권업종대분류코드                          O                          Q
# 상권업종대분류명                          숙박                         음식
# 상권업종중분류코드                        O02                        Q05
# 상권업종중분류명                   모텔/여관/여인숙                     닭/오리요리
# 상권업종소분류코드                     O02A01                     Q05A08
# 상권업종소분류명                   모텔/여관/여인숙                  후라이드/양념치킨
# 표준산업분류코드                      I55112                     I56193
# 표준산업분류명                          여관업                     치킨 전문점
# 시도코드                              26                         26
# 시도명                            부산광역시                      부산광역시
# 시군구코드                          26110                      26260
# 시군구명                              중구                        동래구
# 행정동코드                     2611056000                 2626052000
# 행정동명                             부평동                        복산동
# 법정동코드                     2611012600                 2626010500
# 법정동명                           부평동4가                        복천동
# 지번코드             2611012600100250001        2626010500101850000
# 대지구분코드                             1                          1
# 대지구분명                             대지                         대지
# 지번본번지                             25                        185
# 지번부번지                            1.0                        NaN
# 지번주소             부산광역시 중구 부평동4가 25-1          부산광역시 동래구 복천동 185
# 도로명코드                   261104175163               262604190058
# 도로명                부산광역시 중구 보수대로44번길         부산광역시 동래구 동래로147번길
# 건물본번지                              5                         18
# 건물부번지                            NaN                        NaN
# 건물관리번호     2611012600100250001004473  2626010500101850000016529
# 건물명                              NaN                        NaN
# 도로명주소            부산광역시 중구 보수대로44번길 5      부산광역시 동래구 동래로147번길 18
# 구우편번호                         600074                     607020
# 신우편번호                        48974.0                    47802.0
# 동정보                              NaN                        NaN
# 층정보                              NaN                        NaN
# 호정보                              NaN                        NaN
# 경도                        129.023668                 129.087156
# 위도                         35.100979                  35.205267
#
#                                    2                          3  \
# 상가업소번호                      24659633                   17174094
# 상호명                              스텔라                       도란도란
# 지점명                              NaN                        NaN
# 상권업종대분류코드                          D                          Q
# 상권업종대분류명                          소매                         음식
# 상권업종중분류코드                        D05                        Q01
# 상권업종중분류명                        의복의류                         한식
# 상권업종소분류코드                     D05A01                     Q01A01
# 상권업종소분류명                        일반의류                  한식/백반/한정식
# 표준산업분류코드                      G47416                     I56111
# 표준산업분류명               셔츠 및 기타 의복 소매업                    한식 음식점업
# 시도코드                              26                         26
# 시도명                            부산광역시                      부산광역시
# 시군구코드                          26500                      26230
# 시군구명                             수영구                       부산진구
# 행정동코드                     2650067000                 2623074000
# 행정동명                            남천2동                       개금1동
# 법정동코드                     2650010500                 2623011100
# 법정동명                             남천동                        개금동
# 지번코드             2650010500101480004        2623011100101740004
# 대지구분코드                             1                          1
# 대지구분명                             대지                         대지
# 지번본번지                            148                        174
# 지번부번지                            4.0                        4.0
# 지번주소             부산광역시 수영구 남천동 148-4       부산광역시 부산진구 개금동 174-4
# 도로명코드                   265003138005               262304187020
# 도로명                  부산광역시 수영구 광안해변로       부산광역시 부산진구 가야대로482번길
# 건물본번지                            100                         29
# 건물부번지                            NaN                        3.0
# 건물관리번호     2650010500101480004001694  2623011100101740004050547
# 건물명                            비치아파트                        NaN
# 도로명주소            부산광역시 수영구 광안해변로 100  부산광역시 부산진구 가야대로482번길 29-3
# 구우편번호                         613751                     614813
# 신우편번호                        48305.0                    47327.0
# 동정보                              NaN                        NaN
# 층정보                              NaN                        NaN
# 호정보                              NaN                        NaN
# 경도                        129.115397                 129.024938
# 위도                          35.14377                  35.151645
#
#                                    4
# 상가업소번호                      21683903
# 상호명                            럭키사진관
# 지점명                              NaN
# 상권업종대분류코드                          F
# 상권업종대분류명                       생활서비스
# 상권업종중분류코드                        F06
# 상권업종중분류명                          사진
# 상권업종소분류코드                     F06A01
# 상권업종소분류명                         사진관
# 표준산업분류코드                      M73301
# 표준산업분류명            인물사진 및 행사용비디오 촬영업
# 시도코드                              26
# 시도명                            부산광역시
# 시군구코드                          26380
# 시군구명                             사하구
# 행정동코드                     2638055000
# 행정동명                             당리동
# 법정동코드                     2638010200
# 법정동명                             당리동
# 지번코드             2638010200103250030
# 대지구분코드                             1
# 대지구분명                             대지
# 지번본번지                            325
# 지번부번지                           30.0
# 지번주소            부산광역시 사하구 당리동 325-30
# 도로명코드                   263802006002
# 도로명                   부산광역시 사하구 낙동대로
# 건물본번지                            395
# 건물부번지                            NaN
# 건물관리번호     2638010200103250030010858
# 건물명                              NaN
# 도로명주소             부산광역시 사하구 낙동대로 395
# 구우편번호                         604830
# 신우편번호                        49411.0
# 동정보                              NaN
# 층정보                                1
# 호정보                              NaN
# 경도                        128.974794
# 위도                         35.102905

# %%
# 공백 제거 (모든 문자열 컬럼에 적용)
data = data.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

# %%
# 음식2021 데이터셋 필터링
excluded_categories = ['분식', '유흥주점', '음식배달서비스', '제과제빵떡케익', '커피점/카페', '기타음식업']

food2021 = data[
    (data['상권업종대분류명'] == '음식') &
    (~data['상권업종중분류명'].isin(excluded_categories))
]

# 주점2021 데이터셋 필터링
pub2021 = data[
    (data['상권업종대분류명'] == '음식') &
    (data['상권업종중분류명'] == '유흥주점')
]

# %%
print(food2021['상권업종중분류명'].unique())
# Out:
# ['닭/오리요리' '한식' '양식' '중식' '패스트푸드' '일식/수산물' '별식/퓨전요리' '부페']

# %%
# 필터링된 데이터 확인
print("음식2021 데이터셋:")
food2021.head().T
# Out:
# 음식2021 데이터셋:
#                                   1                          3   \
# 상가업소번호                      20418637                   17174094
# 상호명                            BHC치킨                       도란도란
# 지점명                              동래점                        NaN
# 상권업종대분류코드                          Q                          Q
# 상권업종대분류명                          음식                         음식
# 상권업종중분류코드                        Q05                        Q01
# 상권업종중분류명                      닭/오리요리                         한식
# 상권업종소분류코드                     Q05A08                     Q01A01
# 상권업종소분류명                   후라이드/양념치킨                  한식/백반/한정식
# 표준산업분류코드                      I56193                     I56111
# 표준산업분류명                       치킨 전문점                    한식 음식점업
# 시도코드                              26                         26
# 시도명                            부산광역시                      부산광역시
# 시군구코드                          26260                      26230
# 시군구명                             동래구                       부산진구
# 행정동코드                     2626052000                 2623074000
# 행정동명                             복산동                       개금1동
# 법정동코드                     2626010500                 2623011100
# 법정동명                             복천동                        개금동
# 지번코드             2626010500101850000        2623011100101740004
# 대지구분코드                             1                          1
# 대지구분명                             대지                         대지
# 지번본번지                            185                        174
# 지번부번지                            NaN                        4.0
# 지번주소               부산광역시 동래구 복천동 185       부산광역시 부산진구 개금동 174-4
# 도로명코드                   262604190058               262304187020
# 도로명               부산광역시 동래구 동래로147번길       부산광역시 부산진구 가야대로482번길
# 건물본번지                             18                         29
# 건물부번지                            NaN                        3.0
# 건물관리번호     2626010500101850000016529  2623011100101740004050547
# 건물명                              NaN                        NaN
# 도로명주소          부산광역시 동래구 동래로147번길 18  부산광역시 부산진구 가야대로482번길 29-3
# 구우편번호                         607020                     614813
# 신우편번호                        47802.0                    47327.0
# 동정보                              NaN                        NaN
# 층정보                              NaN                        NaN
# 호정보                              NaN                        NaN
# 경도                        129.087156                 129.024938
# 위도                         35.205267                  35.151645
#
#                                   9                          10  \
# 상가업소번호                      17175332                   17175370
# 상호명                             정성밥상                당감제일냉면&토리커피
# 지점명                              NaN                        NaN
# 상권업종대분류코드                          Q                          Q
# 상권업종대분류명                          음식                         음식
# 상권업종중분류코드                        Q01                        Q01
# 상권업종중분류명                          한식                         한식
# 상권업종소분류코드                     Q01A01                     Q01A19
# 상권업종소분류명                   한식/백반/한정식                        냉면집
# 표준산업분류코드                      I56111                     I56111
# 표준산업분류명                      한식 음식점업                    한식 음식점업
# 시도코드                              26                         26
# 시도명                            부산광역시                      부산광역시
# 시군구코드                          26350                      26530
# 시군구명                            해운대구                        사상구
# 행정동코드                     2635051000                 2653064500
# 행정동명                             우1동                        감전동
# 법정동코드                     2635010500                 2653010500
# 법정동명                              우동                        감전동
# 지번코드             2635010500105520002        2653010500101190018
# 대지구분코드                             1                          1
# 대지구분명                             대지                         대지
# 지번본번지                            552                        119
# 지번부번지                            2.0                       18.0
# 지번주소             부산광역시 해운대구 우동 552-2       부산광역시 사상구 감전동 119-18
# 도로명코드                   263502006010               265303139006
# 도로명                  부산광역시 해운대구 해운대로              부산광역시 사상구 대동로
# 건물본번지                            635                        316
# 건물부번지                            7.0                        NaN
# 건물관리번호     2635010500105520002023290  2653010500101190018025161
# 건물명                              NaN                       당감냉면
# 도로명주소          부산광역시 해운대구 해운대로 635-7          부산광역시 사상구 대동로 316
# 구우편번호                         612819                     617800
# 신우편번호                        48087.0                    46984.0
# 동정보                              NaN                        NaN
# 층정보                              NaN                        NaN
# 호정보                              NaN                        NaN
# 경도                        129.159641                 128.987253
# 위도                         35.164474                    35.1555
#
#                                   11
# 상가업소번호                      17174800
# 상호명                            오도씨곱창
# 지점명                              NaN
# 상권업종대분류코드                          Q
# 상권업종대분류명                          음식
# 상권업종중분류코드                        Q01
# 상권업종중분류명                          한식
# 상권업종소분류코드                     Q01A03
# 상권업종소분류명                    곱창/양구이전문
# 표준산업분류코드                      I56111
# 표준산업분류명                      한식 음식점업
# 시도코드                              26
# 시도명                            부산광역시
# 시군구코드                          26440
# 시군구명                             강서구
# 행정동코드                     2644053500
# 행정동명                            명지1동
# 법정동코드                     2644010400
# 법정동명                             명지동
# 지번코드             2644010400133570007
# 대지구분코드                             1
# 대지구분명                             대지
# 지번본번지                           3357
# 지번부번지                            7.0
# 지번주소            부산광역시 강서구 명지동 3357-7
# 도로명코드                   264403350868
# 도로명                 부산광역시 강서구 명지국제8로
# 건물본번지                            245
# 건물부번지                            NaN
# 건물관리번호     2644010400133570007000001
# 건물명                              NaN
# 도로명주소           부산광역시 강서구 명지국제8로 245
# 구우편번호                         618200
# 신우편번호                        46726.0
# 동정보                              NaN
# 층정보                              NaN
# 호정보                              NaN
# 경도                        128.919857
# 위도                         35.098431

# %%
# 필터링된 데이터 확인
print("\n주점2021 데이터셋:")
pub2021.head().T
# Out:
# 주점2021 데이터셋:
#                                  6                          21   \
# 상가업소번호                      17173895                   19960256
# 상호명                        후라이드참잘하는집                         밤비
# 지점명                            만덕덕천점                        NaN
# 상권업종대분류코드                          Q                          Q
# 상권업종대분류명                          음식                         음식
# 상권업종중분류코드                        Q09                        Q09
# 상권업종중분류명                        유흥주점                       유흥주점
# 상권업종소분류코드                     Q09A01                     Q09A10
# 상권업종소분류명                       호프/맥주                   룸살롱/단란주점
# 표준산업분류코드                      I56219                     I56211
# 표준산업분류명                       기타 주점업                   일반유흥 주점업
# 시도코드                              26                         26
# 시도명                            부산광역시                      부산광역시
# 시군구코드                          26320                      26140
# 시군구명                              북구                         서구
# 행정동코드                     2632057200                 2614064000
# 행정동명                            만덕2동                        충무동
# 법정동코드                     2632010300                 2614012100
# 법정동명                             만덕동                      충무동2가
# 지번코드             2632010300108390001        2614012100100010013
# 대지구분코드                             1                          1
# 대지구분명                             대지                         대지
# 지번본번지                            839                          1
# 지번부번지                            1.0                       13.0
# 지번주소              부산광역시 북구 만덕동 839-1        부산광역시 서구 충무동2가 1-13
# 도로명코드                   263204196122               261404178014
# 도로명                부산광역시 북구 덕천로276번길          부산광역시 서구 구덕로119번길
# 건물본번지                              5                         11
# 건물부번지                            NaN                        NaN
# 건물관리번호     2632010300108390001000805  2614012100100010013013615
# 건물명                             동원맨션                        NaN
# 도로명주소            부산광역시 북구 덕천로276번길 5       부산광역시 서구 구덕로119번길 11
# 구우편번호                         616827                     602012
# 신우편번호                        46611.0                    49253.0
# 동정보                               상가                        NaN
# 층정보                              NaN                        NaN
# 호정보                              NaN                        NaN
# 경도                        129.035638                 129.023122
# 위도                         35.208684                  35.095954
#
#                                  113                        121  \
# 상가업소번호                      28490641                   20038766
# 상호명                              밀크걸                    엠제이노래타운
# 지점명                              NaN                       노래타운
# 상권업종대분류코드                          Q                          Q
# 상권업종대분류명                          음식                         음식
# 상권업종중분류코드                        Q09                        Q09
# 상권업종중분류명                        유흥주점                       유흥주점
# 상권업종소분류코드                     Q09A07                     Q09A10
# 상권업종소분류명                    기타일반유흥주점                   룸살롱/단란주점
# 표준산업분류코드                      I56211                     I56211
# 표준산업분류명                     일반유흥 주점업                   일반유흥 주점업
# 시도코드                              26                         26
# 시도명                            부산광역시                      부산광역시
# 시군구코드                          26470                      26350
# 시군구명                             연제구                       해운대구
# 행정동코드                     2647068000                 2635055100
# 행정동명                            연산4동                        좌1동
# 법정동코드                     2647010200                 2635010700
# 법정동명                             연산동                         좌동
# 지번코드             2647010200107280002        2635010700114610005
# 대지구분코드                             1                          1
# 대지구분명                             대지                         대지
# 지번본번지                            728                       1461
# 지번부번지                            2.0                        5.0
# 지번주소             부산광역시 연제구 연산동 728-2       부산광역시 해운대구 좌동 1461-5
# 도로명코드                   264703130026               263504199127
# 도로명                    부산광역시 연제구 반송로         부산광역시 해운대구 양운로80번길
# 건물본번지                             14                         22
# 건물부번지                            NaN                        NaN
# 건물관리번호     2647010200107280002002945  2635010700114610005000001
# 건물명                              NaN                       해동빌딩
# 도로명주소               부산광역시 연제구 반송로 14      부산광역시 해운대구 양운로80번길 22
# 구우편번호                         611080                     612030
# 신우편번호                        47549.0                    48106.0
# 동정보                              NaN                        NaN
# 층정보                              NaN                        NaN
# 호정보                              NaN                        NaN
# 경도                        129.082881                 129.175201
# 위도                           35.1868                  35.171788
#
#                                  183
# 상가업소번호                      20382500
# 상호명                              조이아
# 지점명                              NaN
# 상권업종대분류코드                          Q
# 상권업종대분류명                          음식
# 상권업종중분류코드                        Q09
# 상권업종중분류명                        유흥주점
# 상권업종소분류코드                     Q09A10
# 상권업종소분류명                    룸살롱/단란주점
# 표준산업분류코드                      I56211
# 표준산업분류명                     일반유흥 주점업
# 시도코드                              26
# 시도명                            부산광역시
# 시군구코드                          26350
# 시군구명                            해운대구
# 행정동코드                     2635052500
# 행정동명                             우3동
# 법정동코드                     2635010500
# 법정동명                              우동
# 지번코드             2635010500114100003
# 대지구분코드                             1
# 대지구분명                             대지
# 지번본번지                           1410
# 지번부번지                            3.0
# 지번주소            부산광역시 해운대구 우동 1410-3
# 도로명코드                   263503133005
# 도로명                부산광역시 해운대구 마린시티3로
# 건물본번지                             52
# 건물부번지                            NaN
# 건물관리번호     2635010500114100003024419
# 건물명                            한화리조트
# 도로명주소           부산광역시 해운대구 마린시티3로 52
# 구우편번호                         612020
# 신우편번호                        48119.0
# 동정보                              NaN
# 층정보                              NaN
# 호정보                              NaN
# 경도                        129.144966
# 위도                         35.154401

# %%
# 음식2022 시군구명 개수 계산 및 정렬
food_city_counts = food2021['시군구명'].value_counts().sort_index()

# 주점2022 시군구명 개수 계산 및 정렬
pub_city_counts = pub2021['시군구명'].value_counts().sort_index()

# %%
# 결과 출력
print("음식2021 시군구명 개수 (가나다순):")
print(food_city_counts)

print("\n주점2021 시군구명 개수 (가나다순):")
print(pub_city_counts)
# Out:
# 음식2021 시군구명 개수 (가나다순):
# 시군구명
# 강서구     1713
# 금정구     2011
# 기장군     2026
# 남구      2073
# 동구       971
# 동래구     2140
# 부산진구    3685
# 북구      1857
# 사상구     1782
# 사하구     2605
# 서구       950
# 수영구     1842
# 연제구     1518
# 영도구     1028
# 중구      1189
# 해운대구    3654
# Name: count, dtype: int64
#
# 주점2021 시군구명 개수 (가나다순):
# 시군구명
# 강서구     148
# 금정구     315
# 기장군     176
# 남구      387
# 동구      228
# 동래구     373
# 부산진구    722
# 북구      304
# 사상구     295
# 사하구     379
# 서구      117
# 수영구     398
# 연제구     245
# 영도구     177
# 중구      246
# 해운대구    436
# Name: count, dtype: int64

# %%
# 필요하면 결과를 각각 CSV로 저장
food_city_counts.to_csv('음식2021_시군구명_개수.csv', index=True, header=['Count'], encoding='utf-8-sig')
pub_city_counts.to_csv('주점2021_시군구명_개수.csv', index=True, header=['Count'], encoding='utf-8-sig')

print("시군구명 개수가 각각 음식2021_시군구명_개수.csv와 주점2021_시군구명_개수.csv로 저장되었습니다.")
# Out:
# 시군구명 개수가 각각 음식2021_시군구명_개수.csv와 주점2021_시군구명_개수.csv로 저장되었습니다.
